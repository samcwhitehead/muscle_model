# %%
from skimage.external import tifffile
import numpy as np

# %%
ref_file_name = '/media/imager/FlyDataD/src/muscle_model/confocal_reference/phalloidin_stained_hemithorax.tif'

# %%
ref_stack = tifffile.TiffFile(ref_file_name).asarray()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
plt.imshow(ref_stack[10],cmap = plt.cm.gray)

# %%
tifdir = '/media/imager/FlyDataD/src/muscle_model/confocal_reference/65G06_muscle_8bit_tpv_layers/'
import os
files = os.listdir(tifdir)

# %%
sortkeys = [f.split('layers')[1].split('.')[0] for f in files]

# %%
#sorted([(int(s),fn) for s,fn in zip(sortkeys,files) if len(s)>0])

# %%
tffile = tifffile.TiffFile(fn)

# %%
#plt.imshow(tffile.asarray(key = 0))

# %%
tifdir = '/media/imager/FlyDataD/src/muscle_model/confocal_reference/65G06_muscle_8bit_i2_layers/'
#tifdir = '/media/imager/FlyDataD/src/muscle_model/confocal_reference/65G06_muscle_8bit_i1_layers'
fns = [tifdir + '/65G06_muscle_8bit_i2_layers%s.tif'%i for i in range(74)]

# %%
# problem with Tpd
stack = np.array([tifffile.TiffFile(fn).asarray(key = 0)[:,:,1] for fn in fns])
#stack = ((stack > 53) & (stack < 255))
plt.imshow(np.sum(stack,axis = 0))
